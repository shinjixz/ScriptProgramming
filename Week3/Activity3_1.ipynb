# %% [markdown]
# Activity 3.1 : Debugging Infinite Loops & Loop Logic Errors
#
# ให้นักศึกษาแก้ไขข้อผิดพลาดของโค้ด

# %% [markdown]
# Activity 3.1 A : Infinite Loop

# %%
# --- Activity 3.1A: Fix the Infinite Loop ---

counter = 0

while counter < 5:
    print(counter)

# %% [markdown]
# Activity 3.1B : Incorrect Range

# %%
# --- Activity 3.1B: Fix the Range ---

# Goal: Print 1, 2, 3, 4, 5

for i in range(1, 5):
    print(i)

# %% [markdown]
# Activity 3.1C : Misplaced Break

# %%
# --- Activity 3.1C: Fix the Break Logic ---

for char in "hello":
    if char == 'l':
        print("Found 'l', stopping!")
        break
    print(char)
